# %%
import pandas as pd
import numpy as np
df = pd.read_csv("pollution_us_2000_2016.csv")
df.head()

df = df.drop(columns=['Unnamed: 0', 'Site Num', 'Address', 'City'])
pd.unique(df['O3 Units'])

df.isna().sum()

d = df.dropna()
df['SO2 AQI'] = df.groupby(['County', 'Date Local'])['SO2 AQI'].ffill()
df['CO AQI'] = df.groupby(['County', 'Date Local'])['CO AQI'].bfill()
df.isna().sum()
df = df.dropna()
df.isna().sum()
df.to_csv("pollution.csv")

d = pd.read_csv("pollution.csv")

d
# Out:
#          Unnamed: 0  State Code  County Code    State    County  Date Local  \
# 0                 0           4           13  Arizona  Maricopa  2000-01-01
# 1                 1           4           13  Arizona  Maricopa  2000-01-01
# 2                 2           4           13  Arizona  Maricopa  2000-01-01
# 3                 3           4           13  Arizona  Maricopa  2000-01-01
# 4                 4           4           13  Arizona  Maricopa  2000-01-02
# ...             ...         ...          ...      ...       ...         ...
# 1746339     1746656          56           21  Wyoming   Laramie  2016-03-30
# 1746340     1746657          56           21  Wyoming   Laramie  2016-03-31
# 1746341     1746658          56           21  Wyoming   Laramie  2016-03-31
# 1746342     1746659          56           21  Wyoming   Laramie  2016-03-31
# 1746343     1746660          56           21  Wyoming   Laramie  2016-03-31
#
# ...

# %%
df = pd.read_csv("pollution.csv")
UniqueID = []
FIPS = []

dfsub = df.loc[:,['State', 'County', 'State Code', 'County Code']]
dfloc = dfsub.astype({'State Code': str, 'County Code': str})

# find fips in pollution
dfloc = dfloc.replace({'State Code': {'0': '0', '1': '01', '2': '02', '3': '03', '4': '04', '5': '05', '6': '06', '7': '07', '8': '08', '9':'09'}})
fips_list = []
for i in dfloc['County Code']:
  if int(i) < 10:
    fips_list.append("00" + i)
  elif int(i) < 100:
    fips_list.append("0" + i)
  else:
    fips_list.append(i)
dfloc['County Code'] = fips_list

FIPS = dfloc['State Code'] + dfloc['County Code']
# Find date table in PD

dfdate = df.loc[:,['State', 'Date Local']]
dfdate = dfdate.loc[:,['Date Local']]
ymd = []


for info in dfdate['Date Local']:
  info_str = str(info)
  info_split = info_str.split('-')
  ymd.append(info_split[0] + info_split[1] + info_split[2])

for i in range(len(df)):
  UniqueID.append(i+1)

UniqueID = np.array(UniqueID)
FIPS = np.array(FIPS)
print(FIPS)
ymd = np.array(ymd)
dfdate['ymd'] = ymd

df['UniqueID'] = UniqueID
df['FIPS'] = FIPS
df['YMD'] = dfdate['ymd']
 
SO2 = df[['UniqueID','SO2 AQI','SO2 Mean', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'FIPS','YMD']]

NO2 = df[['UniqueID','NO2 AQI','NO2 Mean', 'NO2 1st Max Value', 'NO2 1st Max Hour','FIPS','YMD']]

CO =  df[['UniqueID','CO AQI','CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour','FIPS','YMD']]

O3 = df[['UniqueID','O3 AQI','O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour','FIPS','YMD']]

SO2.to_csv("SO2.csv")
NO2.to_csv("NO2.csv")
O3.to_csv("O3.csv")
CO.to_csv("CO.csv")

CO
# Out:
# ['04013' '04013' '04013' ... '56021' '56021' '56021']
#          UniqueID  CO AQI   CO Mean  CO 1st Max Value  CO 1st Max Hour   FIPS  \
# 0               1    25.0  1.145833             4.200               21  04013
# 1               2    25.0  0.878947             2.200               23  04013
# 2               3    25.0  1.145833             4.200               21  04013
# 3               4    25.0  0.878947             2.200               23  04013
# 4               5    26.0  0.850000             1.600               23  04013
# ...           ...     ...       ...               ...              ...    ...
# 1746339   1746340     1.0  0.091667             0.100                2  56021
# 1746340   1746341     1.0  0.067714             0.127                0  56021
# 1746341   1746342     1.0  0.100000             0.100                0  56021
# 1746342   1746343     1.0  0.067714             0.127                0  56021
# ...

# %%
CO.dtypes
# Out:
# UniqueID              int64
# CO AQI              float64
# CO Mean             float64
# CO 1st Max Value    float64
# CO 1st Max Hour       int64
# FIPS                 object
# YMD                  object
# dtype: object

# %%
each_line = []
with open('CO.csv') as f:
    lines = f.readlines()
    # print(lines[2])
    # i = 3
    for line in lines:
      line_split = line.split(',')
      txt = "(" + line_split[1] + "," + line_split[2] + "," + line_split[3] + "," + line_split[4] + "," + line_split[5] + ",'" + line_split[6] + "','" + line_split[7][:-1] + "'),"
      each_line.append(txt)
      # i -= 1
      # if (i == 0):
      #   break
    # print(each_line[2])
f.close()

with open('CO_for_sql.txt', 'w') as f1:
    for line in each_line:
        f1.write(line)
        f1.write('\n')
f1.close()

# %%
each_line_small = each_line[-10000:]
print(each_line_small[0])
print(each_line_small[-1])
with open('CO_for_sql_small.txt', 'w') as f1:
    for line in each_line_small:
        f1.write(line)
        f1.write('\n')
f1.close()
# Out:
# (1736345,3.0,0.246435,0.303,4,'25025','20160218'),
# (1746344,1.0,0.1,0.1,0,'56021','20160331'),

# %%
each_line = []
with open('SO2.csv') as f:
    lines = f.readlines()
    for line in lines:
      line_split = line.split(',')
      txt = "(" + line_split[1] + "," + line_split[2] + "," + line_split[3] + "," + line_split[4] + "," + line_split[5] + ",'" + line_split[6] + "','" + line_split[7][:-1] + "'),"
      each_line.append(txt)
f.close()

with open('SO2_for_sql.txt', 'w') as f1:
    for line in each_line:
        f1.write(line)
        f1.write('\n')
f1.close()

each_line_small = each_line[-10000:]
print(each_line_small[0])
print(each_line_small[-1])
with open('SO2_for_sql_small.txt', 'w') as f1:
    for line in each_line_small:
        f1.write(line)
        f1.write('\n')
f1.close()
# Out:
# (1736345,0.0,0.245833,0.5,10,'25025','20160218'),
# (1746344,0.0,0.0,0.0,5,'56021','20160331'),

# %%
each_line = []
with open('NO2.csv') as f:
    lines = f.readlines()
    for line in lines:
      line_split = line.split(',')
      txt = "(" + line_split[1] + "," + line_split[2] + "," + line_split[3] + "," + line_split[4] + "," + line_split[5] + ",'" + line_split[6] + "','" + line_split[7][:-1] + "'),"
      each_line.append(txt)
f.close()

with open('NO2_for_sql.txt', 'w') as f1:
    for line in each_line:
        f1.write(line)
        f1.write('\n')
f1.close()

each_line_small = each_line[-10000:]
print(each_line_small[0])
print(each_line_small[-1])
with open('NO2_for_sql_small.txt', 'w') as f1:
    for line in each_line_small:
        f1.write(line)
        f1.write('\n')
f1.close()
# Out:
# (1736345,19,12.272727,20.0,6,'25025','20160218'),
# (1746344,1,0.93913,1.3,5,'56021','20160331'),

# %%
each_line = []
with open('O3.csv') as f:
    lines = f.readlines()
    for line in lines:
      line_split = line.split(',')
      txt = "(" + line_split[1] + "," + line_split[2] + "," + line_split[3] + "," + line_split[4] + "," + line_split[5] + ",'" + line_split[6] + "','" + line_split[7][:-1] + "'),"
      each_line.append(txt)
f.close()

with open('O3_for_sql.txt', 'w') as f1:
    for line in each_line:
        f1.write(line)
        f1.write('\n')
f1.close()

each_line_small = each_line[-10000:]
print(each_line_small[0])
print(each_line_small[-1])
with open('O3_for_sql_small.txt', 'w') as f1:
    for line in each_line_small:
        f1.write(line)
        f1.write('\n')
f1.close()
# Out:
# (1736345,27,0.023875,0.029,8,'25025','20160218'),
# (1746344,44,0.045263,0.047,9,'56021','20160331'),
